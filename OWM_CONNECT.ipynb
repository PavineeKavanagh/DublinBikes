# %%
import requests
import json
import time
import mysql.connector

# %%
# Configuration values for mysql connection

config = {
    'user': 'root',
    'password': '00001234',
    'host': 'dublinbikescomp30670.c8lbidkpdn4h.us-east-2.rds.amazonaws.com',
    'database': 'dublinbikes',
    'raise_on_warnings': True,
}

cnx = mysql.connector.connect(**config) # ------------------------- Connecting to RDS
cursor = cnx.cursor()                   # ------------------------- Cursor to execute all the queries
stations = json.loads(response.text)    # ------------------------- Loading JSON Data

# %%
response = requests.get('http://api.openweathermap.org/data/2.5/forecast?id=7778677&APPID=26025aec9fb58721adba291f0f3291f2')
response1 = requests.get('https://api.jcdecaux.com/vls/v1/stations?contract=Dublin&apiKey=72ad8bb012e2e3c42c7d2c9665b3b9f875d03bac')

# %%
weather = json.loads(response.text)

# %%
weather
# Out:
# {'city': {'coord': {'lat': 53.3551, 'lon': -6.2493},
#   'country': 'IE',
#   'id': 7778677,
#   'name': 'Dublin City'},
#  'cnt': 40,
#  'cod': '200',
#  'list': [{'clouds': {'all': 48},
#    'dt': 1520964000,
#    'dt_txt': '2018-03-13 18:00:00',
#    'main': {'grnd_level': 1013.95,
#     'humidity': 94,
#     'pressure': 1013.95,
#     'sea_level': 1018.64,
#     'temp': 281.72,
#     'temp_kf': 1.45,
#     'temp_max': 281.72,
#     'temp_min': 280.278},
#    'rain': {'3h': 0.035},
#    'sys': {'pod': 'd'},
#    'weather': [{'description': 'light rain',
#      'icon': '10d',
#      'id': 500,
#      'main': 'Rain'}],
#    'wind': {'deg': 172, 'speed': 7.96}},
#   {'clouds': {'all': 48},
#    'dt': 1520974800,
#    'dt_txt': '2018-03-13 21:00:00',
#    'main': {'grnd_level': 1012.57,
#     'humidity': 94,
#     'pressure': 1012.57,
#     'sea_level': 1017.4,
#     'temp': 281.4,
#     'temp_kf': 1.08,
#     'temp_max': 281.4,
#     'temp_min': 280.312},
#    'rain': {'3h': 0.08},
# ...

# %%
# Insert statement to insert values for dublin bike database in the schema ---- %s is the placeholder for the values
add_weather = ("INSERT INTO openweathermap_dublin_bikes_dump "
                   "(weather_id, weather_date, weather_main_temp,weather_main_temp_min,weather_main_temp_max, weather_main_pressure, openweathermap_dublin_bikes_dumpcol, weather_city_coord, weather_main_sea_level, weather_main_grnd_level, weather_main_temp_kf, weather_weather_id, weather_weather_main, weather_weather_des, weather_weather_icon, weather_clouds_all, weather_wind_speed, weather_wind_deg, weather_snow, weather_sys_pod, weather_sys_dt_txt, weather_city_id, weather_city_name, weather_city_coord_lat, weather_city_coord_lan, weather_city_coord_country ) "
                   "VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s,%s,%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s,%s,%s)")

# %%
for weather in weathermap:
    weather_id = weather['id']
    weather_date = weather['dt']
    weather_main_temp = weather['temp']
    weather_main_temp_min = weather['temp_min']
    weather_main_temp_max = weather['temp_max']
    weather_main_pressure = weather['pressure'] 
    weather_city_coord = weather[''] 
    weather_main_sea_level 
    weather_main_grnd_level 
    weather_main_temp_kf
    weather_weather_id
    weather_weather_main
    weather_weather_des
    weather_weather_icon
    weather_clouds_all
    weather_wind_speed
    weather_wind_deg
    weather_snow
    weather_sys_pod
    weather_sys_dt_txt
    weather_city_id
    weather_city_name
    weather_city_coord_lat, weather_city_coord_lan, weather_city_coord_country

# %%
from mysql.connector import errorcode
import mysql.connector
config = {
        'user': 'root',
        'password': '00001234',
        'host': 'dublinbikescomp30670.c8lbidkpdn4h.us-east-2.rds.amazonaws.com',
        'database': 'dublinbikes',
        'raise_on_warnings': True,
}

try:
    cnx = mysql.connector.connect(**config)
except mysql.connector.Error as err:
    if err.errno == errorcode.ER_ACCESS_DENIED_ERROR:
        print("Something is wrong with your user name or password")
    elif err.errno == errorcode.ER_BAD_DB_ERROR:
        print("Database does not exist")
    else:
        print(err)

cursor = cnx.cursor()

staticStations = ("Select * from jcdecaux_static_dublin_bikes")

try:
    cursor.execute(staticStations) # -------- Execute on database and return values in cursor
except mysql.connector.Error as err:
    print("Could not retrieve static stations, Error: {}".format(err))
stations=[]
for i in cursor:
    station = dict(StationNum=i[1],StationName=i[2],StationAddr=i[3],Latitude=float(i[4]),Longitude=float(i[5]))
    stations.append(station)

# %%
from flask import json
test = json.dumps(stations)

# %%
new_stats = []
for stats in stations:
    stats = dict(lat=float(stats['Latitude']),lng=float(stats['Longitude']))
    new_stats.append(stats)

# %%
print(new_stats)
# Out:
# [{'lat': 53.349562, 'lng': -6.278198}, {'lat': 53.353462, 'lng': -6.265305}, {'lat': 53.336021, 'lng': -6.26298}, {'lat': 53.33796, 'lng': -6.24153}, {'lat': 53.343368, 'lng': -6.27012}, {'lat': 53.334123, 'lng': -6.265436}, {'lat': 53.344304, 'lng': -6.250427}, {'lat': 53.338755, 'lng': -6.262003}, {'lat': 53.347777, 'lng': -6.244239}, {'lat': 53.336074, 'lng': -6.252825}, {'lat': 53.330091, 'lng': -6.268044}, {'lat': 53.339983, 'lng': -6.295594}, {'lat': 53.350929, 'lng': -6.265125}, {'lat': 53.341515, 'lng': -6.256853}, {'lat': 53.344603, 'lng': -6.263371}, {'lat': 53.340927, 'lng': -6.262501}, {'lat': 53.348279, 'lng': -6.254662}, {'lat': 53.344115, 'lng': -6.237153}, {'lat': 53.343893, 'lng': -6.280531}, {'lat': 53.347477, 'lng': -6.28525}, {'lat': 53.339005, 'lng': -6.300217}, {'lat': 53.344153, 'lng': -6.233451}, {'lat': 53.334019, 'lng': -6.258371}, {'lat': 53.340803, 'lng': -6.267732}, {'lat': 53.351464, 'lng': -6.255265}, {'lat': 53.343105, 'lng': -6.277167}, {'lat': 53.341
# ...
